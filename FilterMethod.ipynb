# %% [markdown]
# <a href="https://colab.research.google.com/github/sayeemabdullah/Machine-Learning-Feature-Selection/blob/master/FilterMethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

url_eeg = 'https://raw.githubusercontent.com/sayeemabdullah/Machine-Learning-Classifiers/master/Dataset/EEG_data.csv'
url_demo = 'https://raw.githubusercontent.com/sayeemabdullah/Machine-Learning-Classifiers/master/Dataset/demographic_info.csv'
df_eeg = pd.read_csv(url_eeg)
df_demo = pd.read_csv(url_demo)
# print(columns)
df_eeg.drop(['SubjectID', 'VideoID', 'predefinedlabel'], axis='columns', inplace=True)
columns = df_eeg.columns.drop('user-definedlabeln')
# print(columns)
X = df_eeg.drop('user-definedlabeln',axis=1).values
y = df_eeg['user-definedlabeln'].values

plt.figure(figsize=(12,10))
cor = df_eeg.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor["user-definedlabeln"])

# %%
relevant_features = cor_target[cor_target>0]
relevant_features
# Out:
# Attention             0.119088
# Mediation             0.023502
# Raw                   0.001465
# Delta                 0.148588
# Theta                 0.147558
# Alpha1                0.121711
# Alpha2                0.107238
# Beta1                 0.111482
# Beta2                 0.019556
# Gamma1                0.011316
# Gamma2                0.053533
# user-definedlabeln    1.000000
# Name: user-definedlabeln, dtype: float64

# %%
relevant_features = cor_target[cor_target>0.01]
relevant_features
# Out:
# Attention             0.119088
# Mediation             0.023502
# Delta                 0.148588
# Theta                 0.147558
# Alpha1                0.121711
# Alpha2                0.107238
# Beta1                 0.111482
# Beta2                 0.019556
# Gamma1                0.011316
# Gamma2                0.053533
# user-definedlabeln    1.000000
# Name: user-definedlabeln, dtype: float64

# %%
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# Attention             0.119088
# Delta                 0.148588
# Theta                 0.147558
# Alpha1                0.121711
# Alpha2                0.107238
# Beta1                 0.111482
# user-definedlabeln    1.000000
# Name: user-definedlabeln, dtype: float64
